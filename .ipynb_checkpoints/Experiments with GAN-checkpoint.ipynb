# %%
import numpy as np
from torch import Tensor, randn, ones, zeros, optim, save
from torch.nn import Module, Sequential, Linear, ReLU, Sigmoid, Tanh, Dropout, BCELoss
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torchvision import transforms
from sklearn.preprocessing import MinMaxScaler

# %%
def loadData(path):
    data = np.genfromtxt(path, delimiter=',')
    scaler = MinMaxScaler(feature_range=(-1,1))
    data = scaler.fit_transform(data)
    return Tensor(data)
        
def generateNoise(N):
    noise = Variable(randn(N, 100))
    return noise

def createBatches(data):
    batches = DataLoader(data, batch_size=100, shuffle=True)
    return batches

# %%
class Generator(Module):
    def __init__(self):
        super(Generator, self).__init__()
        d_input = 100
        d_output = 28*28
        
        self.input = Sequential(
            Linear(d_input, 256),
            ReLU()
        )
        self.hidden1 = Sequential(            
            Linear(256, 512),
            ReLU()
        )
        self.hidden2 = Sequential(
            Linear(512, 1024),
            ReLU()
        )
        self.output = Sequential(
            Linear(1024, d_output),
            Tanh()
        )
        
    def forward(self, x):
        x = self.input(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.output(x)
        return x

# %%
class Discriminator(Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        d_input = 28*28
        d_output = 1
        
        self.input = Sequential( 
            Linear(d_input, 1024),
            ReLU(),
            Dropout(0.2)
        )
        self.hidden1 = Sequential(
            Linear(1024, 512),
            ReLU(),
            Dropout(0.2)
        )
        self.hidden2 = Sequential(
            Linear(512, 256),
            ReLU(),
            Dropout(0.2)
        )
        self.output = Sequential(
            Linear(256, d_output),
            Sigmoid()
        )
    def forward(self, x):
        x = self.input(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.output(x)
        return x

# %%
""" 
Train Generator 

"""
def train_d(optim, trueData, falseData):
    trueN = trueData.size(0)
    falseN = falseData.size(0)
        
    # Train on true data
    optim.zero_grad()
    truePred = discriminator(trueData)
    trueError = loss(truePred, Variable(ones(trueN, 1)))
    trueError.backward()

    # Train on generated data
    falsePred = discriminator(falseData)
    falseError = loss(falsePred, Variable(zeros(falseN, 1)))
    falseError.backward()
    
    optim.step()

    return trueError + falseError

""" 
Train Generator based on Discriminators response 

"""
def train_g(optim, falseData):
    falseN = falseData.size(0)
    optim.zero_grad()

    pred = discriminator(falseData) # Response from Discriminator
    error = loss(pred, Variable(ones(falseN, 1))) # Pretending that the false data is true data
    error.backward()
    optim.step()
    
    return error

# %%
data = loadData('fashion_mnist.csv')
batches = createBatches(data)

# %%
epochs = 200
generator = Generator()
discriminator = Discriminator()

g_optim = optim.Adam(generator.parameters(), lr=2e-4)
d_optim = optim.Adam(discriminator.parameters(), lr=2e-4)
loss = BCELoss()

errors_G = []
errors_D = []

print('-------- Training models --------')
for epoch in range(1, epochs):
    for n_batch, batch in enumerate(batches):
        # Train Discriminator
        trueData = Variable(batch)
        falseData = generator(generateNoise(batch.size(0))).detach() # detach to not calculate gradients
        error_d = train_d(d_optim, trueData, falseData)

        # Train Generator
        falseData = generator(generateNoise(batch.size(0)))
        error_g = train_g(g_optim, falseData)
    
    print('Epoch', epoch)
    print('Generator Error:', error_g.data[0])
    print('Discriminator Error:', error_d.data[0])
    print()
    
    errors_G.append(error_g.data[0])
    errors_D.append(error_d.data[0])
print('-------- Finished training --------')   

save(generator.state_dict(), 'generator.pt')
save(discriminator.state_dict(), 'discriminator.pt')

figG, axG = plt.subplots()
axG.plot(range(1, epochs), errors_G)
axG.set_xlabel('epoch')
axG.set_ylabel('error')
axG.set_title('Generator')
figG.savefig('errorG.png')


figD, axD = plt.subplots()
axD.plot(range(1, epochs), errors_D)
axD.set_xlabel('epoch')
axD.set_ylabel('error')
axD.set_title('Discriminator')
figD.savefig('errorD.png')
# Out:
# -------- Training models --------
# Epoch 1
# Generator Error: 6.585610866546631
# Discriminator Error: 0.06657128781080246
#
# Epoch 2
# Generator Error: 6.290902614593506
# Discriminator Error: 0.21591618657112122
#
# Epoch 3
# Generator Error: 4.079988479614258
# Discriminator Error: 0.1162613108754158
#
# Epoch 4
# Generator Error: 4.1981401443481445
# Discriminator Error: 0.2441917061805725
#
# Epoch 5
# Generator Error: 5.203634738922119
# Discriminator Error: 0.25047945976257324
#
# Epoch 6
# Generator Error: 4.225180149078369
# Discriminator Error: 0.28376469016075134
#
# Epoch 7
# Generator Error: 2.705981731414795
# Discriminator Error: 0.2871397137641907
#
# Epoch 8
# Generator Error: 3.551867723464966
# Discriminator Error: 0.3300721347332001
#
# Epoch 9
# Generator Error: 3.054715633392334
# Discriminator Error: 0.3615506887435913
#
# Epoch 10
# Generator Error: 2.5832839012145996
# Discriminator Error: 0.506671667098999
#
# Epoch 11
# Generator Error: 2.673696279525757
# Discriminator Error: 0.42720502614974976
#
# Epoch 12
# Generator Error: 2.605177640914917
# Discriminator Error: 0.48984259366989136
#
# Epoch 13
# Generator Error: 2.0984725952148438
# Discriminator Error: 0.5461567640304565
#
# Epoch 14
# Generator Error: 2.237971067428589
# Discriminator Error: 0.5739851593971252
#
# Epoch 15
# Generator Error: 2.0314199924468994
# Discriminator Error: 0.863739013671875
#
# Epoch 16
# Generator Error: 2.058840751647949
# Discriminator Error: 0.5988718271255493
#
# Epoch 17
# Generator Error: 1.994206428527832
# Discriminator Error: 0.7648954391479492
#
# Epoch 18
# Generator Error: 1.9467753171920776
# Discriminator Error: 0.8774687051773071
#
# Epoch 19
# Generator Error: 2.044191837310791
# Discriminator Error: 0.6613218784332275
#
# Epoch 20
# Generator Error: 1.678533673286438
# Discriminator Error: 0.6634787321090698
#
# Epoch 21
# Generator Error: 1.973892092704773
# Discriminator Error: 0.7140927910804749
#
# Epoch 22
# Generator Error: 1.7155076265335083
# Discriminator Error: 0.772944450378418
#
# Epoch 23
# Generator Error: 1.796554446220398
# Discriminator Error: 0.9234898090362549
#
# Epoch 24
# Generator Error: 1.7031760215759277
# Discriminator Error: 0.7287592887878418
#
# Epoch 25
# Generator Error: 1.5788366794586182
# Discriminator Error: 0.9214639663696289
#
# Epoch 26
# Generator Error: 1.5156170129776
# Discriminator Error: 0.9198276996612549
#
# Epoch 27
# Generator Error: 1.7058371305465698
# Discriminator Error: 0.8095301985740662
#
# Epoch 28
# Generator Error: 1.3109750747680664
# Discriminator Error: 0.9326241612434387
#
# Epoch 29
# Generator Error: 1.2982045412063599
# Discriminator Error: 0.9713772535324097
#
# Epoch 30
# Generator Error: 1.0010579824447632
# Discriminator Error: 1.2795805931091309
#
# Epoch 31
# Generator Error: 1.222519040107727
# Discriminator Error: 1.026078701019287
#
# Epoch 32
# Generator Error: 1.4002047777175903
# Discriminator Error: 1.0504499673843384
#
# Epoch 33
# Generator Error: 1.427996039390564
# Discriminator Error: 0.8736752271652222
#
# Epoch 34
# Generator Error: 1.349543809890747
# Discriminator Error: 0.9142221212387085
#
# Epoch 35
# Generator Error: 1.1916555166244507
# Discriminator Error: 0.7716918587684631
#
# Epoch 36
# Generator Error: 1.3064148426055908
# Discriminator Error: 0.9924135208129883
#
# Epoch 37
# Generator Error: 1.314458966255188
# Discriminator Error: 1.1739509105682373
#
# Epoch 38
# Generator Error: 1.3460201025009155
# Discriminator Error: 0.9710876941680908
#
# Epoch 39
# Generator Error: 1.1026253700256348
# Discriminator Error: 1.0575650930404663
#
# Epoch 40
# Generator Error: 1.3612269163131714
# Discriminator Error: 0.867908239364624
#
# Epoch 41
# Generator Error: 1.2470413446426392
# Discriminator Error: 0.8884831666946411
#
# Epoch 42
# Generator Error: 1.0807877779006958
# Discriminator Error: 1.2695648670196533
#
# Epoch 43
# Generator Error: 1.2262743711471558
# Discriminator Error: 1.1381710767745972
#
# Epoch 44
# Generator Error: 1.2767616510391235
# Discriminator Error: 0.8878470659255981
#
# Epoch 45
# Generator Error: 1.1487269401550293
# Discriminator Error: 1.0551934242248535
#
# Epoch 46
# Generator Error: 1.209493637084961
# Discriminator Error: 1.1634912490844727
#
# Epoch 47
# Generator Error: 1.1326371431350708
# Discriminator Error: 1.277582049369812
#
# Epoch 48
# Generator Error: 1.1274640560150146
# Discriminator Error: 1.0363059043884277
#
# Epoch 49
# Generator Error: 1.2064933776855469
# Discriminator Error: 1.3428263664245605
#
# Epoch 50
# Generator Error: 1.3699699640274048
# Discriminator Error: 0.8337401747703552
#
# Epoch 51
# Generator Error: 1.4203263521194458
# Discriminator Error: 1.0384364128112793
#
# Epoch 52
# Generator Error: 1.1556899547576904
# Discriminator Error: 0.8502380847930908
#
# Epoch 53
# Generator Error: 1.1048760414123535
# Discriminator Error: 0.8663784265518188
#
# Epoch 54
# Generator Error: 1.0897465944290161
# Discriminator Error: 1.1339952945709229
#
# Epoch 55
# Generator Error: 1.1163640022277832
# Discriminator Error: 0.9352172613143921
#
# Epoch 56
# Generator Error: 1.1471370458602905
# Discriminator Error: 1.0997323989868164
#
# Epoch 57
# Generator Error: 1.1959341764450073
# Discriminator Error: 1.3093173503875732
#
# Epoch 58
# Generator Error: 1.137076735496521
# Discriminator Error: 0.8858609199523926
#
# Epoch 59
# Generator Error: 1.249881625175476
# Discriminator Error: 1.4660332202911377
#
# Epoch 60
# Generator Error: 0.9985153079032898
# Discriminator Error: 1.289859414100647
#
# Epoch 61
# Generator Error: 1.0574958324432373
# Discriminator Error: 1.034847378730774
#
# Epoch 62
# Generator Error: 1.1986018419265747
# Discriminator Error: 1.135443925857544
#
# Epoch 63
# Generator Error: 1.1714030504226685
# Discriminator Error: 1.0395514965057373
#
# Epoch 64
# Generator Error: 1.1011319160461426
# Discriminator Error: 1.1399331092834473
#
# Epoch 65
# Generator Error: 1.1357223987579346
# Discriminator Error: 1.0181752443313599
#
# Epoch 66
# Generator Error: 1.1143467426300049
# Discriminator Error: 1.1533255577087402
#
# Epoch 67
# Generator Error: 1.1336801052093506
# Discriminator Error: 1.0438387393951416
#
# Epoch 68
# Generator Error: 1.0387365818023682
# Discriminator Error: 0.985471248626709
#
# Epoch 69
# Generator Error: 1.1501274108886719
# Discriminator Error: 1.0288690328598022
#
# Epoch 70
# Generator Error: 1.1459423303604126
# Discriminator Error: 1.0192347764968872
#
# Epoch 71
# Generator Error: 1.0899317264556885
# Discriminator Error: 1.0982598066329956
#
# Epoch 72
# Generator Error: 1.120253324508667
# Discriminator Error: 1.087083101272583
#
# Epoch 73
# Generator Error: 1.094659686088562
# Discriminator Error: 1.090968132019043
#
# Epoch 74
# Generator Error: 1.0714839696884155
# Discriminator Error: 1.125064730644226
#
# Epoch 75
# Generator Error: 1.0535776615142822
# Discriminator Error: 1.0839338302612305
#
# Epoch 76
# Generator Error: 1.1612087488174438
# Discriminator Error: 1.1016740798950195
#
# Epoch 77
# Generator Error: 1.1423428058624268
# Discriminator Error: 1.094208002090454
#
# Epoch 78
# Generator Error: 1.1465425491333008
# Discriminator Error: 1.2666118144989014
#
# Epoch 79
# Generator Error: 1.0763839483261108
# Discriminator Error: 1.1638171672821045
#
# Epoch 80
# Generator Error: 1.1061569452285767
# Discriminator Error: 1.0609469413757324
#
# Epoch 81
# Generator Error: 1.0831644535064697
# Discriminator Error: 1.0612237453460693
#
# Epoch 82
# Generator Error: 1.3478302955627441
# Discriminator Error: 0.9725059270858765
#
# Epoch 83
# Generator Error: 1.0882455110549927
# Discriminator Error: 1.0924928188323975
#
# Epoch 84
# Generator Error: 1.0990509986877441
# Discriminator Error: 1.1403104066848755
#
# Epoch 85
# Generator Error: 1.1533915996551514
# Discriminator Error: 0.9919925928115845
#
# Epoch 86
# Generator Error: 1.062394380569458
# Discriminator Error: 1.162217617034912
#
# Epoch 87
# Generator Error: 1.1562339067459106
# Discriminator Error: 1.0391135215759277
#
# Epoch 88
# Generator Error: 1.1368669271469116
# Discriminator Error: 1.1129217147827148
#
# Epoch 89
# Generator Error: 1.0643162727355957
# Discriminator Error: 1.187180995941162
#
# Epoch 90
# Generator Error: 1.073297381401062
# Discriminator Error: 1.0944106578826904
#
# Epoch 91
# Generator Error: 1.2142361402511597
# Discriminator Error: 1.024370789527893
#
# Epoch 92
# Generator Error: 1.0571142435073853
# Discriminator Error: 1.0895094871520996
#
# Epoch 93
# Generator Error: 1.0552114248275757
# Discriminator Error: 1.0830951929092407
#
# Epoch 94
# Generator Error: 1.2224626541137695
# Discriminator Error: 1.1282179355621338
#
# Epoch 95
# Generator Error: 1.0539711713790894
# Discriminator Error: 1.2145799398422241
#
# Epoch 96
# Generator Error: 1.0408579111099243
# Discriminator Error: 0.985880970954895
# Epoch 97
# Generator Error: 1.2624363899230957
# Discriminator Error: 1.0272928476333618
#
# Epoch 98
# Generator Error: 1.1193019151687622
# Discriminator Error: 1.018295168876648
#
# Epoch 99
# Generator Error: 1.2085599899291992
# Discriminator Error: 1.0281447172164917
#
# Epoch 100
# Generator Error: 1.174302101135254
# Discriminator Error: 1.0751324892044067
#
# Epoch 101
# Generator Error: 1.2388075590133667
# Discriminator Error: 0.9954402446746826
#
# Epoch 102
# Generator Error: 1.0610524415969849
# Discriminator Error: 0.9604381322860718
#
# Epoch 103
# Generator Error: 1.0269018411636353
# Discriminator Error: 1.0476651191711426
#
# Epoch 104
# Generator Error: 1.211050033569336
# Discriminator Error: 1.0557975769042969
#
# Epoch 105
# Generator Error: 1.0241918563842773
# Discriminator Error: 1.1133673191070557
#
# Epoch 106
# Generator Error: 1.1918383836746216
# Discriminator Error: 1.141908884048462
#
# Epoch 107
# Generator Error: 1.148067831993103
# Discriminator Error: 1.0034575462341309
#
# Epoch 108
# Generator Error: 1.171406626701355
# Discriminator Error: 1.1649181842803955
#
# Epoch 109
# Generator Error: 1.0848809480667114
# Discriminator Error: 1.0814380645751953
#
# Epoch 110
# Generator Error: 1.1385608911514282
# Discriminator Error: 1.1070693731307983
#
# Epoch 111
# Generator Error: 1.1335886716842651
# Discriminator Error: 1.0590711832046509
#
# Epoch 112
# Generator Error: 1.129158854484558
# Discriminator Error: 1.0583007335662842
#
# Epoch 113
# Generator Error: 1.1728790998458862
# Discriminator Error: 0.9905502796173096
#
# Epoch 114
# Generator Error: 1.1376625299453735
# Discriminator Error: 1.1115777492523193
#
# Epoch 115
# Generator Error: 1.1689103841781616
# Discriminator Error: 0.9657562971115112
#
# Epoch 116
# Generator Error: 1.0729621648788452
# Discriminator Error: 1.0611227750778198
#
# Epoch 117
# Generator Error: 1.1128846406936646
# Discriminator Error: 1.101717233657837
#
# Epoch 118
# Generator Error: 1.0954327583312988
# Discriminator Error: 1.120082139968872
#
# Epoch 119
# Generator Error: 1.2051376104354858
# Discriminator Error: 0.9990776777267456
#
# Epoch 120
# Generator Error: 1.128115177154541
# Discriminator Error: 1.1061370372772217
#
# Epoch 121
# Generator Error: 1.2042078971862793
# Discriminator Error: 1.0804312229156494
#
# Epoch 122
# Generator Error: 1.1708611249923706
# Discriminator Error: 1.015303373336792
#
# Epoch 123
# Generator Error: 1.063052773475647
# Discriminator Error: 1.0621204376220703
#
# Epoch 124
# Generator Error: 1.0839765071868896
# Discriminator Error: 0.9605751037597656
#
# Epoch 125
# Generator Error: 1.2430176734924316
# Discriminator Error: 1.0767312049865723
#
# Epoch 126
# Generator Error: 1.2106422185897827
# Discriminator Error: 1.179694414138794
#
# Epoch 127
# Generator Error: 1.1501017808914185
# Discriminator Error: 1.03871488571167
#
# Epoch 128
# Generator Error: 1.2102290391921997
# Discriminator Error: 0.9199842810630798
#
# Epoch 129
# Generator Error: 1.0734524726867676
# Discriminator Error: 1.1284464597702026
#
# Epoch 130
# Generator Error: 1.1230822801589966
# Discriminator Error: 1.078737497329712
#
# Epoch 131
# Generator Error: 1.1920942068099976
# Discriminator Error: 1.1750025749206543
#
# Epoch 132
# Generator Error: 1.145524501800537
# Discriminator Error: 0.9857075214385986
#
# Epoch 133
# Generator Error: 1.0880581140518188
# Discriminator Error: 1.1529994010925293
#
# Epoch 134
# Generator Error: 1.256323218345642
# Discriminator Error: 1.0018872022628784
#
# Epoch 135
# Generator Error: 1.295466423034668
# Discriminator Error: 1.0021710395812988
#
# Epoch 136
# Generator Error: 1.1831278800964355
# Discriminator Error: 1.0991785526275635
#
# Epoch 137
# Generator Error: 1.1823936700820923
# Discriminator Error: 1.0689154863357544
#
# Epoch 138
# Generator Error: 1.2398889064788818
# Discriminator Error: 0.9976962804794312
#
# Epoch 139
# Generator Error: 1.162255883216858
# Discriminator Error: 0.9900381565093994
#
# Epoch 140
# Generator Error: 1.135758399963379
# Discriminator Error: 1.1667113304138184
#
# Epoch 141
# Generator Error: 1.1600582599639893
# Discriminator Error: 1.0678448677062988
#
# Epoch 142
# Generator Error: 1.2012521028518677
# Discriminator Error: 1.1272845268249512
#
# Epoch 143
# Generator Error: 1.4131489992141724
# Discriminator Error: 1.0152008533477783
#
# Epoch 144
# Generator Error: 1.1294960975646973
# Discriminator Error: 0.9732503294944763
#
# Epoch 145
# Generator Error: 1.2017394304275513
# Discriminator Error: 1.0146684646606445
#
# Epoch 146
# Generator Error: 1.1637672185897827
# Discriminator Error: 0.9916939735412598
#
# Epoch 147
# Generator Error: 1.2217535972595215
# Discriminator Error: 1.0606606006622314
#
# Epoch 148
# Generator Error: 1.2175718545913696
# Discriminator Error: 1.0091562271118164
#
# Epoch 149
# Generator Error: 1.2485500574111938
# Discriminator Error: 0.9623726606369019
#
# Epoch 150
# Generator Error: 1.1604734659194946
# Discriminator Error: 1.136195421218872
#
# Epoch 151
# Generator Error: 1.1855634450912476
# Discriminator Error: 0.9963918924331665
#
# Epoch 152
# Generator Error: 1.1010385751724243
# Discriminator Error: 1.0161871910095215
#
# Epoch 153
# Generator Error: 1.198296308517456
# Discriminator Error: 1.0364065170288086
#
# Epoch 154
# Generator Error: 1.2370036840438843
# Discriminator Error: 1.0928633213043213
#
# Epoch 155
# Generator Error: 1.2347335815429688
# Discriminator Error: 1.012842059135437
#
# Epoch 156
# Generator Error: 1.3254592418670654
# Discriminator Error: 0.9450278878211975
#
# Epoch 157
# Generator Error: 1.2227531671524048
# Discriminator Error: 0.9222192764282227
#
# Epoch 158
# Generator Error: 1.2740123271942139
# Discriminator Error: 1.187833309173584
#
# Epoch 159
# Generator Error: 1.094467282295227
# Discriminator Error: 0.9327086210250854
#
# Epoch 160
# Generator Error: 1.1909503936767578
# Discriminator Error: 1.0008208751678467
#
# Epoch 161
# Generator Error: 1.3652211427688599
# Discriminator Error: 0.9523679614067078
#
# Epoch 162
# Generator Error: 1.2360814809799194
# Discriminator Error: 1.1322429180145264
#
# Epoch 163
# Generator Error: 1.3248738050460815
# Discriminator Error: 1.0784660577774048
#
# Epoch 164
# Generator Error: 1.2669057846069336
# Discriminator Error: 0.9619529247283936
#
# Epoch 165
# Generator Error: 1.2350003719329834
# Discriminator Error: 1.0105665922164917
#
# Epoch 166
# Generator Error: 1.2084062099456787
# Discriminator Error: 0.9707571268081665
#
# Epoch 167
# Generator Error: 1.1207489967346191
# Discriminator Error: 1.0151877403259277
#
# Epoch 168
# Generator Error: 1.2427709102630615
# Discriminator Error: 1.0053499937057495
#
# Epoch 169
# Generator Error: 1.2183749675750732
# Discriminator Error: 1.0114777088165283
#
# Epoch 170
# Generator Error: 1.3082215785980225
# Discriminator Error: 1.111418604850769
#
# Epoch 171
# Generator Error: 1.3431288003921509
# Discriminator Error: 1.0732589960098267
#
# Epoch 172
# Generator Error: 1.300650954246521
# Discriminator Error: 1.021868348121643
#
# Epoch 173
# Generator Error: 1.2574453353881836
# Discriminator Error: 0.8972241878509521
#
# Epoch 174
# Generator Error: 1.321873664855957
# Discriminator Error: 0.9909070730209351
#
# Epoch 175
# Generator Error: 1.2227635383605957
# Discriminator Error: 1.0065240859985352
#
# Epoch 176
# Generator Error: 1.2078580856323242
# Discriminator Error: 0.9185866117477417
#
# Epoch 177
# Generator Error: 1.218930721282959
# Discriminator Error: 1.0310100317001343
#
# Epoch 178
# Generator Error: 1.228074312210083
# Discriminator Error: 1.086144208908081
#
# Epoch 179
# Generator Error: 1.4141384363174438
# Discriminator Error: 0.9913060069084167
#
# Epoch 180
# Generator Error: 1.318305253982544
# Discriminator Error: 1.0654383897781372
#
# Epoch 181
# Generator Error: 1.2667896747589111
# Discriminator Error: 0.8631539344787598
#
# Epoch 182
# Generator Error: 1.1961480379104614
# Discriminator Error: 0.9233882427215576
#
# Epoch 183
# Generator Error: 1.3836495876312256
# Discriminator Error: 0.8500854969024658
#
# Epoch 184
# Generator Error: 1.4486896991729736
# Discriminator Error: 1.0326298475265503
#
# Epoch 185
# Generator Error: 1.3055554628372192
# Discriminator Error: 0.9764543771743774
#
# Epoch 186
# Generator Error: 1.2669636011123657
# Discriminator Error: 1.041020154953003
#
# Epoch 187
# Generator Error: 1.301091194152832
# Discriminator Error: 0.9328902959823608
#
# Epoch 188
# Generator Error: 1.2002285718917847
# Discriminator Error: 0.9936621189117432
#
# Epoch 189
# Generator Error: 1.3046526908874512
# Discriminator Error: 1.018670678138733
#
# Epoch 190
# Generator Error: 1.336074948310852
# Discriminator Error: 1.165052890777588
#
# Epoch 191
# Generator Error: 1.231348991394043
# Discriminator Error: 0.9812573194503784
# Epoch 192
# Generator Error: 1.2430617809295654
# Discriminator Error: 0.9720213413238525
#
# Epoch 193
# Generator Error: 1.3644235134124756
# Discriminator Error: 1.0251013040542603
#
# Epoch 194
# Generator Error: 1.3536027669906616
# Discriminator Error: 0.8513145446777344
#
# Epoch 195
# Generator Error: 1.3220752477645874
# Discriminator Error: 0.8891733288764954
#
# Epoch 196
# Generator Error: 1.3438664674758911
# Discriminator Error: 0.867490828037262
#
# Epoch 197
# Generator Error: 1.2495372295379639
# Discriminator Error: 0.9362081289291382
#
# Epoch 198
# Generator Error: 1.386513113975525
# Discriminator Error: 1.0462803840637207
#
# Epoch 199
# Generator Error: 1.3919624090194702
# Discriminator Error: 0.9366355538368225
#
# -------- Finished training --------

# %%
generator = Generator()
model.load_state_dict(torch.load('generator.pt'))

testData = generator(generateNoise(100))

for image in testData:
    image = image.view(28,28).data
    plt.imshow(image, cmap='Greys')
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-147af3c84040> in <module>()
# ----> 1 generator = Generator()
#       2 model.load_state_dict(torch.load('generator.pt'))
#       3
#       4 testData = generator(generateNoise(100))
#       5
#
# NameError: name 'Generator' is not defined
